# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import gym
import torch
import numpy as np
from loguru import logger
from torch.optim import Adam
import matplotlib.pyplot as plt
from IPython.display import Image

from src.utils import (
    device,
    set_seed,
    eval_policy,
    demo_policy,
    plot_returns,
    save_frames_as_gif
)

plt.ion()

# %%
SEED: int = 42
ENVIRONMENT_NAME: str='LunarLander-v2'

# torch related defaults
DEVICE = device()
torch.set_default_dtype(torch.float32)
# Out:
# 2024-10-18 14:59:43.153 | INFO     | src.utils:device:51 - Using cpu device.

# %%
# Use random seeds for reproducibility
set_seed(SEED)

# instantiate the environment
environment = gym.make(ENVIRONMENT_NAME)

# get the state and action dimensions
num_actions = environment.action_space.n
state_dimension = environment.observation_space.shape[0]
# Out:
# 2024-10-18 13:21:47.996 | INFO     | src.utils:set_seed:37 - Random seed set as 42.

# %% [markdown]
# ***

# %% [markdown]
# ## 1. REINFORCE

# %%
from src.networks import Policy
from src.reinforce import train_one_epoch as reinforce_epoch

################################## Hyper-parameters Tuning ##################################

EPOCHS: int = 200
HIDDEN_DIMENSION: int = 24
LEARNING_RATE: float = 0.03

#############################################################################################

# Instantiate the policy network
policy = Policy(
    state_dimension, num_actions, hidden_dimension=HIDDEN_DIMENSION
).to(DEVICE)

# Learn the policy
optimizer = Adam(policy.parameters(), LEARNING_RATE)

# Loop for each epoch
mean_returns, std_returns = [], []
for epoch in range(EPOCHS):
    reinforce_epoch(environment, policy, optimizer)
    
    episode_return_mean, episode_return_std = eval_policy(policy, ENVIRONMENT_NAME)
    mean_returns.append(episode_return_mean)
    std_returns.append(episode_return_std)
    
    logger.info(f'Epoch: {epoch:3d} \t return: {episode_return_mean:.2f}')

    if epoch:
        plot_returns(
            mean_returns, std_returns, method_name='reinforce', dynamic=True
        )

# %%
plot_returns(
    mean_returns, std_returns, method_name='reinforce'
)

# %%
frames = demo_policy(
    policy, ENVIRONMENT_NAME
)
gif_path = save_frames_as_gif(frames, method_name='reinforce')
Image(open(gif_path,'rb').read())
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.

# %% [markdown]
# ***

# %% [markdown]
# ## 2. Simple Q-iteration (no experience replay + target network)

# %%
from src.networks import ValueFunctionQ
from src.q_iter import train_one_epoch as q_iter_epoch

################################## Hyper-parameters Tuning ##################################

EPOCHS: int = 10
HIDDEN_DIMENSION: int = 4
LEARNING_RATE: float = 1e-1

#############################################################################################

# Instantiate the state-action value function, Q
Q = ValueFunctionQ(
    state_dimension, num_actions, hidden_dimension=HIDDEN_DIMENSION
).to(DEVICE)
# Learn the policy
optimizer = Adam(Q.parameters(), LEARNING_RATE)

mean_returns, std_returns = [], []
for epoch in range(EPOCHS):
    q_iter_epoch(env=environment, Q=Q, optimizer=optimizer)
    
    episode_return_mean, episode_return_std = eval_policy(Q, ENVIRONMENT_NAME)
    mean_returns.append(episode_return_mean)
    std_returns.append(episode_return_std)
    
    from src.q_iter import eps
    
    logger.info(f'Epoch: {epoch:3d}, \t return: {episode_return_mean:.2f}, \t eps: {eps:.2f}')

    if epoch:
        plot_returns(
            mean_returns, std_returns, method_name='dqn', dynamic=True
        )

# %%
plot_returns(
    mean_returns, std_returns, method_name='q_iteration'
)

# %%
frames = demo_policy(
    Q, ENVIRONMENT_NAME
)
gif_path = save_frames_as_gif(frames, method_name='q_iteration')
Image(open(gif_path,'rb').read())

# %% [markdown]
# ***

# %% [markdown]
# ## Experience Replay Buffer/Memory

# %%
from src.buffer import ReplayBuffer
################################## Hyper-parameters Tuning ##################################

BATCH_SIZE: int = 2048
#############################################################################################

# instantiate the memory replay buffer
memory = ReplayBuffer(
    capacity=10_000, batch_size=BATCH_SIZE
)

# %% [markdown]
# ***

# %% [markdown]
# ## 3. DQN (Deep Q-learning + experience replay + target network)

# %%
from src.networks import ValueFunctionQ
from src.dqn import train_one_epoch as dqn_epoch

################################## Hyper-parameters Tuning ##################################

EPOCHS: int = 10
HIDDEN_DIMENSION: int = 4
LEARNING_RATE: float = 1e-1

#############################################################################################

# instantiate the state-action value function, Q
Q = ValueFunctionQ(
    state_dimension, num_actions, hidden_dimension=HIDDEN_DIMENSION
).to(DEVICE)
# initialize the target network
target_Q = ValueFunctionQ(
    state_dimension, num_actions, hidden_dimension=HIDDEN_DIMENSION
).to(DEVICE)

# Learn the policy
optimizer = Adam(Q.parameters(), LEARNING_RATE)

memory.clear()
mean_returns, std_returns = [], []
for epoch in range(EPOCHS):
    
    # copy target network params
    target_Q.load_state_dict(Q.state_dict())

    dqn_epoch(
        env=environment, Q=Q, target_Q=target_Q,
        memory=memory, optimizer=optimizer
    )
    
    episode_return_mean, episode_return_std = eval_policy(Q, ENVIRONMENT_NAME)
    mean_returns.append(episode_return_mean)
    std_returns.append(episode_return_std)

    from src.dqn import eps
    
    logger.info(f'Epoch: {epoch:3d}, \t return: {episode_return_mean:.2f}, \t eps: {eps:.2f}')

    if epoch:
        plot_returns(
            mean_returns, std_returns, method_name='dqn', dynamic=True
        )

# %%
plot_returns(
    mean_returns, std_returns, method_name='dqn'
)

# %%
frames = demo_policy(
    Q, ENVIRONMENT_NAME
)
gif_path = save_frames_as_gif(frames, method_name='dqn')
Image(open(gif_path,'rb').read())

# %% [markdown]
# ***

# %% [markdown]
# ## 4. Actor-Critic

# %%
from src.networks import Policy
from src.networks import ValueFunctionQ
from src.ac import train_one_epoch as ac_epoch

################################## Hyper-parameters Tuning ##################################

EPOCHS: int = 300
HIDDEN_DIMENSION: int = 128
LEARNING_RATE: float = 0.005

#############################################################################################

# instantiate the state-action value function, Q
Q = ValueFunctionQ(
    state_dimension, num_actions, hidden_dimension=HIDDEN_DIMENSION
).to(DEVICE)
# initialize the target network
target_Q = ValueFunctionQ(
    state_dimension, num_actions, hidden_dimension=HIDDEN_DIMENSION
).to(DEVICE)
# initialize the policy network
policy = Policy(
    state_dimension, num_actions, hidden_dimension=HIDDEN_DIMENSION
).to(DEVICE)

# Learn the policy and Q
optimizer_Q = Adam(Q.parameters(), lr=LEARNING_RATE)
optimizer_pi = Adam(policy.parameters(), lr=LEARNING_RATE)

memory.clear()
mean_returns, std_returns = [], []
for epoch in range(EPOCHS):

    # copy target network params
    target_Q.load_state_dict(Q.state_dict())
    
    ac_epoch(
        env=environment,
        policy=policy, Q=Q, target_Q=target_Q,
        memory=memory, optimizer_Q=optimizer_Q, optimizer_pi=optimizer_pi
    )
    
    episode_return_mean, episode_return_std = eval_policy(policy, ENVIRONMENT_NAME)
    mean_returns.append(episode_return_mean)
    std_returns.append(episode_return_std)
    
    logger.info(f'Epoch: {epoch:3d} \t return: {episode_return_mean:.2f}')

    if epoch:
        plot_returns(
            mean_returns, std_returns, method_name='ac', dynamic=True
        )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 37
#      32 for epoch in range(EPOCHS):
#      33
#      34     # copy target network params
#      35     target_Q.load_state_dict(Q.state_dict())
# ---> 37     ac_epoch(
#      38         env=environment,
#      39         policy=policy, Q=Q, target_Q=target_Q,
#      40         memory=memory, optimizer_Q=optimizer_Q, optimizer_pi=optimizer_pi
#      41     )
#      43     episode_return_mean, episode_return_std = eval_policy(policy, ENVIRONMENT_NAME)
#      44     mean_returns.append(episode_return_mean)
#
# File c:\Users\ibaali3\Github\cs8803drl-fall24\hw1\src\ac.py:151, in train_one_epoch(env, policy, Q, target_Q, memory, optimizer_Q, optimizer_pi, gamma)
#     149     optimize_Q(Q, target_Q, policy, gamma, batch, optimizer_Q)
#     150     #Q.eval(), policy.train()
# --> 151     optimize_policy(policy, Q, batch, optimizer_pi)
#     152 state = next_state
#     153 if terminated or truncated:
#
# File c:\Users\ibaali3\Github\cs8803drl-fall24\hw1\src\ac.py:91, in optimize_policy(policy, Q, batch, optimizer)
#      83 def optimize_policy(
#      84         policy: Policy,
#      85         Q: ValueFunctionQ,
#      86         batch: Transition,
#      87         optimizer: Optimizer
#      88 ):
#      89     states = np.stack(batch.state)
# ---> 91     actions, log_probabilities = policy.sample_multiple(states)
#      93     actions = actions.unsqueeze(-1)
#      94     log_probabilities = log_probabilities.unsqueeze(-1)
#
# File c:\Users\ibaali3\Github\cs8803drl-fall24\hw1\src\networks.py:132, in Policy.sample_multiple(self, states)
#     130 log_probs = []
#     131 for state in states:
# --> 132     (action, log_prob) = self.sample(state)
#     133     actions.append(action)
#     134     log_probs.append(log_prob)
#
# File c:\Users\ibaali3\Github\cs8803drl-fall24\hw1\src\networks.py:114, in Policy.sample(self, state)
#     112 distribution = self.pi(state)
#     113 action = distribution.sample()
# --> 114 log_prob = distribution.log_prob(action)
#     115 return (action.item(), log_prob)
#
# File c:\Users\ibaali3\Github\cs8803drl-fall24\cs8803drl\lib\site-packages\torch\distributions\categorical.py:140, in Categorical.log_prob(self, value)
#     138     self._validate_sample(value)
#     139 value = value.long().unsqueeze(-1)
# --> 140 value, log_pmf = torch.broadcast_tensors(value, self.logits)
#     141 value = value[..., :1]
#     142 return log_pmf.gather(-1, value).squeeze(-1)
#
# File c:\Users\ibaali3\Github\cs8803drl-fall24\cs8803drl\lib\site-packages\torch\functional.py:77, in broadcast_tensors(*tensors)
#      75 if has_torch_function(tensors):
#      76     return handle_torch_function(broadcast_tensors, tensors, *tensors)
# ---> 77 return _VF.broadcast_tensors(tensors)
#
# KeyboardInterrupt:

# %%
plot_returns(
    mean_returns, std_returns, method_name='ac'
)

# %%
frames = demo_policy(
    policy, ENVIRONMENT_NAME,
)
gif_path = save_frames_as_gif(frames, method_name='ac')
Image(open(gif_path,'rb').read())
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.

# %% [markdown]
# ***
